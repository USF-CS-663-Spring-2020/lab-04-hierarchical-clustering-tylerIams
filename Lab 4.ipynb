# %%
import pandas as pd

# %% [markdown]
# Let's read in the data and check it out.  Looks like it has nearly 2000 observations and 69 features

# %%
df = pd.read_csv('USCensus1990-2000rows.data.txt')
df
# Out:
#       caseid  dAge  dAncstry1  dAncstry2  iAvail  iCitizen  iClass  dDepart  \
# 0      10000     5          0          1       0         0       5        3
# 1      10001     6          1          1       0         0       7        5
# 2      10002     3          1          2       0         0       7        4
# 3      10003     4          1          2       0         0       1        3
# 4      10004     7          1          1       0         0       0        0
# ...      ...   ...        ...        ...     ...       ...     ...      ...
# 1994   11994     7          1          1       0         3       0        0
# 1995   11995     4          1          1       0         0       1        3
# 1996   11996     4          1          1       0         0       2        3
# 1997   11997     2          2          1       0         4       0        0
# 1998   11998     3          1          1       0         0       0        0
#
# ...

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

Z = linkage(df, 'ward')

# %% [markdown]
# Now we've got Z, so let's draw the dendrogram for the first dataset

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure()
dendrogram(Z)
plt.show()

# %% [markdown]
# Now let's read in the second dataset, this one is a lot bigger, with over 11,000 observations and over 5,800 features

# %%
df2 = pd.read_csv('NIPS_1987-2015.csv')

# %%
df2 = df2.drop('Unnamed: 0', 1)

# %%
Z2 = linkage(df2, 'ward')

# %%
# %matplotlib inline

plt.figure()
dendrogram(Z2)
plt.show()
